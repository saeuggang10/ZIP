# %%
import time
import os

import urllib.request
from bs4 import BeautifulSoup

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
IMAGE = input("검색할 이미지를 입력하세요: ")
CNT = int(input("저장할 이미지 개수를 입력하세요: "))
### Chrome web 사용.
options = webdriver.ChromeOptions()                     # Chrome 창의 옵션을 설정할 수 있는 코드.
options.add_argument('--no-sandbox')                    
options.add_argument('--disable-dev-shm-usage')         
# options.add_argument('--headless')                      # headless : Broswer 창을 띄우지 않고 수행 (colab에서는 필수).
# options.add_argument("window-size = 1920,1080")       # window size 설정


browser = webdriver.Chrome(options = options)           # 위 Option을 적용한 Chrome 창을 실행.
browser.maximize_window()

# %%
### 이미지를 검색할 페이지 이동
url = "https://www.naver.com"
browser.get(url)

### 이미지 검색
elem = browser.find_element(By.NAME, "query")
elem.send_keys(IMAGE)
elem.send_keys(Keys.ENTER)
time.sleep(3)   # 검색 완료까지 대기. 

### 이미지 탭 클릭
elem = browser.find_element(By.XPATH, '//*[@id="lnb"]/div[1]/div/div[1]/div/div[1]/div[2]/a')
elem.click()
time.sleep(3)

# %%
### 이미지 크롤링
img = browser.find_elements(By.CSS_SELECTOR, '._fe_image_tab_content_thumbnail_image')
# 수집한 이미지 태그에서 src 속성값 수집
img_list = [i.get_attribute('src') for i in img]


### 이미지 저장할 폴더 생성
if not os.path.exists("./naver_img"):
    os.makedirs("./naver_img")

    
### 이미지 저장
print("%d개의 이미지 저장 시작!" % (CNT))
for idx, img_url in enumerate(img_list, 1):
    urllib.request.urlretrieve(img_url, "./naver_img/" + IMAGE + str(idx) + ".jpg")
    print("%d번쩨 이미지 저장 완료" % (idx))


### 브라우저 종료
print("%d개의 이미지 저장 완료 후 브라우저 종료!" % (CNT))
browser.quit()
# Out:
# 200개의 이미지 저장 시작!
# 1번쩨 이미지 저장 완료
# 2번쩨 이미지 저장 완료
# 3번쩨 이미지 저장 완료
# 4번쩨 이미지 저장 완료
# 5번쩨 이미지 저장 완료
# 6번쩨 이미지 저장 완료
# 7번쩨 이미지 저장 완료
# 8번쩨 이미지 저장 완료
# 9번쩨 이미지 저장 완료
# 10번쩨 이미지 저장 완료
# 11번쩨 이미지 저장 완료
# 12번쩨 이미지 저장 완료
# 13번쩨 이미지 저장 완료
# 14번쩨 이미지 저장 완료
# 15번쩨 이미지 저장 완료
# 16번쩨 이미지 저장 완료
# 17번쩨 이미지 저장 완료
# 18번쩨 이미지 저장 완료
# 19번쩨 이미지 저장 완료
# 20번쩨 이미지 저장 완료
# 21번쩨 이미지 저장 완료
# 22번쩨 이미지 저장 완료
# 23번쩨 이미지 저장 완료
# 24번쩨 이미지 저장 완료
# 25번쩨 이미지 저장 완료
# 26번쩨 이미지 저장 완료
# 27번쩨 이미지 저장 완료
# 28번쩨 이미지 저장 완료
# 29번쩨 이미지 저장 완료
# 30번쩨 이미지 저장 완료
# 31번쩨 이미지 저장 완료
# 32번쩨 이미지 저장 완료
# 33번쩨 이미지 저장 완료
# 34번쩨 이미지 저장 완료
# 35번쩨 이미지 저장 완료
# 36번쩨 이미지 저장 완료
# 37번쩨 이미지 저장 완료
# 38번쩨 이미지 저장 완료
# 39번쩨 이미지 저장 완료
# 40번쩨 이미지 저장 완료
# 41번쩨 이미지 저장 완료
# 42번쩨 이미지 저장 완료
# 43번쩨 이미지 저장 완료
# 44번쩨 이미지 저장 완료
# 45번쩨 이미지 저장 완료
# 46번쩨 이미지 저장 완료
# 47번쩨 이미지 저장 완료
# 48번쩨 이미지 저장 완료
# 49번쩨 이미지 저장 완료
# 50번쩨 이미지 저장 완료
# 51번쩨 이미지 저장 완료
# 52번쩨 이미지 저장 완료
# 53번쩨 이미지 저장 완료
# 54번쩨 이미지 저장 완료
# 55번쩨 이미지 저장 완료
# 56번쩨 이미지 저장 완료
# 57번쩨 이미지 저장 완료
# 58번쩨 이미지 저장 완료
# 59번쩨 이미지 저장 완료
# 60번쩨 이미지 저장 완료
# 61번쩨 이미지 저장 완료
# 62번쩨 이미지 저장 완료
# 63번쩨 이미지 저장 완료
# 64번쩨 이미지 저장 완료
# 65번쩨 이미지 저장 완료
# 66번쩨 이미지 저장 완료
# 67번쩨 이미지 저장 완료
# 68번쩨 이미지 저장 완료
# 69번쩨 이미지 저장 완료
# 70번쩨 이미지 저장 완료
# 71번쩨 이미지 저장 완료
# 72번쩨 이미지 저장 완료
# 73번쩨 이미지 저장 완료
# 74번쩨 이미지 저장 완료
# 75번쩨 이미지 저장 완료
# 76번쩨 이미지 저장 완료
# 77번쩨 이미지 저장 완료
# 78번쩨 이미지 저장 완료
# 79번쩨 이미지 저장 완료
# 80번쩨 이미지 저장 완료
# 81번쩨 이미지 저장 완료
# 82번쩨 이미지 저장 완료
# 83번쩨 이미지 저장 완료
# 84번쩨 이미지 저장 완료
# 85번쩨 이미지 저장 완료
# 86번쩨 이미지 저장 완료
# 87번쩨 이미지 저장 완료
# 88번쩨 이미지 저장 완료
# 89번쩨 이미지 저장 완료
# 90번쩨 이미지 저장 완료
# 91번쩨 이미지 저장 완료
# 92번쩨 이미지 저장 완료
# 93번쩨 이미지 저장 완료
# 94번쩨 이미지 저장 완료
# 95번쩨 이미지 저장 완료
# 96번쩨 이미지 저장 완료
# 97번쩨 이미지 저장 완료
# 98번쩨 이미지 저장 완료
# 99번쩨 이미지 저장 완료
# 100번쩨 이미지 저장 완료
# 101번쩨 이미지 저장 완료
# 102번쩨 이미지 저장 완료
# 103번쩨 이미지 저장 완료
# 104번쩨 이미지 저장 완료
# 105번쩨 이미지 저장 완료
# 106번쩨 이미지 저장 완료
# 107번쩨 이미지 저장 완료
# 108번쩨 이미지 저장 완료
# 109번쩨 이미지 저장 완료
# 110번쩨 이미지 저장 완료
# 111번쩨 이미지 저장 완료
# 112번쩨 이미지 저장 완료
# 113번쩨 이미지 저장 완료
# 114번쩨 이미지 저장 완료
# 115번쩨 이미지 저장 완료
# 116번쩨 이미지 저장 완료
# 117번쩨 이미지 저장 완료
# 118번쩨 이미지 저장 완료
# 119번쩨 이미지 저장 완료
# 120번쩨 이미지 저장 완료
# 121번쩨 이미지 저장 완료
# 122번쩨 이미지 저장 완료
# 123번쩨 이미지 저장 완료
# 124번쩨 이미지 저장 완료
# 125번쩨 이미지 저장 완료
# 126번쩨 이미지 저장 완료
# 127번쩨 이미지 저장 완료
# 128번쩨 이미지 저장 완료
# 129번쩨 이미지 저장 완료
# 130번쩨 이미지 저장 완료
# 131번쩨 이미지 저장 완료
# 132번쩨 이미지 저장 완료
# 133번쩨 이미지 저장 완료
# 134번쩨 이미지 저장 완료
# 135번쩨 이미지 저장 완료
# 136번쩨 이미지 저장 완료
# 137번쩨 이미지 저장 완료
# 138번쩨 이미지 저장 완료
# 139번쩨 이미지 저장 완료
# 140번쩨 이미지 저장 완료
# 141번쩨 이미지 저장 완료
# 142번쩨 이미지 저장 완료
# 143번쩨 이미지 저장 완료
# 144번쩨 이미지 저장 완료
# 145번쩨 이미지 저장 완료
# 146번쩨 이미지 저장 완료
# 147번쩨 이미지 저장 완료
# 148번쩨 이미지 저장 완료
# 149번쩨 이미지 저장 완료
# 150번쩨 이미지 저장 완료
# 151번쩨 이미지 저장 완료
# 152번쩨 이미지 저장 완료
# 153번쩨 이미지 저장 완료
# 154번쩨 이미지 저장 완료
# 155번쩨 이미지 저장 완료
# 156번쩨 이미지 저장 완료
# 157번쩨 이미지 저장 완료
# 158번쩨 이미지 저장 완료
# 159번쩨 이미지 저장 완료
# 160번쩨 이미지 저장 완료
# 161번쩨 이미지 저장 완료
# 162번쩨 이미지 저장 완료
# 163번쩨 이미지 저장 완료
# 164번쩨 이미지 저장 완료
# 165번쩨 이미지 저장 완료
# 166번쩨 이미지 저장 완료
# 167번쩨 이미지 저장 완료
# 168번쩨 이미지 저장 완료
# 169번쩨 이미지 저장 완료
# 170번쩨 이미지 저장 완료
# 171번쩨 이미지 저장 완료
# 172번쩨 이미지 저장 완료
# 173번쩨 이미지 저장 완료
# 174번쩨 이미지 저장 완료
# 175번쩨 이미지 저장 완료
# 176번쩨 이미지 저장 완료
# 177번쩨 이미지 저장 완료
# 178번쩨 이미지 저장 완료
# 179번쩨 이미지 저장 완료
# 180번쩨 이미지 저장 완료
# 181번쩨 이미지 저장 완료
# 182번쩨 이미지 저장 완료
# 183번쩨 이미지 저장 완료
# 184번쩨 이미지 저장 완료
# 185번쩨 이미지 저장 완료
# 186번쩨 이미지 저장 완료
# 187번쩨 이미지 저장 완료
# 188번쩨 이미지 저장 완료
# 189번쩨 이미지 저장 완료
# 190번쩨 이미지 저장 완료
# 191번쩨 이미지 저장 완료
# 192번쩨 이미지 저장 완료
# 193번쩨 이미지 저장 완료
# 194번쩨 이미지 저장 완료
# 195번쩨 이미지 저장 완료
# 196번쩨 이미지 저장 완료
# 197번쩨 이미지 저장 완료
# 198번쩨 이미지 저장 완료
# 199번쩨 이미지 저장 완료
# 200번쩨 이미지 저장 완료
# 200개의 이미지 저장 완료 후 브라우저 종료!
